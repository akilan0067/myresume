# %% [markdown]
# <a href="https://colab.research.google.com/github/akilan0067/myresume/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/IMDb Movies India.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# (15509, 10)

# %%
df.isna().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
df.dropna(subset=['Rating','Year'], inplace=True)

# %%
df['Rating']
# Out:
# 1        7.0
# 3        4.4
# 5        4.7
# 6        7.4
# 8        5.6
#         ...
# 15501    5.3
# 15503    5.8
# 15504    4.6
# 15505    4.5
# 15508    6.2
# Name: Rating, Length: 7919, dtype: float64

# %%
df.hist(column=['Rating'])
# Out:
# array([[<Axes: title={'center': 'Rating'}>]], dtype=object)

# %%
df.loc[df['Votes']==df['Votes'].max()]
# Out:
#                                        Name    Year Duration           Genre  \
# 12569  Satyam Shivam Sundaram: Love Sublime  (1978)  172 min  Drama, Romance
#
#        Rating Votes    Director        Actor 1      Actor 2  \
# 12569     7.1   999  Raj Kapoor  Shashi Kapoor  Zeenat Aman
#
#                       Actor 3
# 12569  Kanhaiyalal Chaturvedi

# %%
df
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15501                     Zulm Ki Hukumat  (1992)      NaN
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes           Director  \
# 1                          Drama     7.0      8      Gaurav Bakshi
# 3                Comedy, Romance     4.4     35         Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6            Drama, Romance, War     7.4  1,086     Shoojit Sircar
# 8      Horror, Mystery, Thriller     5.6    326      Allyson Patel
# ...                          ...     ...    ...                ...
# 15501       Action, Crime, Drama     5.3    135  Bharat Rangachary
# 15503       Action, Crime, Drama     5.8     44    S.P. Muthuraman
# 15504                     Action     4.6     11      Mahendra Shah
# 15505              Action, Drama     4.5    655         Kuku Kohli
# 15508              Action, Drama     6.2     20       K.C. Bokadia
#
#                 Actor 1                 Actor 2          Actor 3
# 1          Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 3               Prateik              Ishita Raj  Siddhant Kapoor
# 5            Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6       Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 8             Yash Dave          Muntazir Ahmad     Kiran Bhatia
# ...                 ...                     ...              ...
# 15501        Dharmendra     Moushumi Chatterjee          Govinda
# 15503       Chiranjeevi              Jayamalini      Rajinikanth
# 15504  Naseeruddin Shah           Sumeet Saigal    Suparna Anand
# 15505      Akshay Kumar          Twinkle Khanna      Aruna Irani
# 15508        Dharmendra              Jaya Prada      Arjun Sarja
#
# [7919 rows x 10 columns]

# %%
df.dropna(subset=['Genre'], inplace=True)

# %%
df=df.reset_index()

# %%
df.head()
# Out:
#    index                                Name    Year Duration  \
# 0      1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 1      3                             #Yaaram  (2019)  110 min
# 2      5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 3      6                           ...Yahaan  (2005)  142 min
# 4      8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 0                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 1            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 2     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 3        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 4  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 0          Vivek Ghamande    Arvind Jangid
# 1              Ishita Raj  Siddhant Kapoor
# 2  Aishwarya Rai Bachchan    Shammi Kapoor
# 3          Minissha Lamba   Yashpal Sharma
# 4          Muntazir Ahmad     Kiran Bhatia

# %%
list_Genre=[]
list_Genre=df['Genre'].str.split(",")
list_Genre
# Out:
# 0                             [Drama]
# 1                  [Comedy,  Romance]
# 2          [Comedy,  Drama,  Musical]
# 3             [Drama,  Romance,  War]
# 4       [Horror,  Mystery,  Thriller]
#                     ...
# 7812         [Action,  Crime,  Drama]
# 7813         [Action,  Crime,  Drama]
# 7814                         [Action]
# 7815                 [Action,  Drama]
# 7816                 [Action,  Drama]
# Name: Genre, Length: 7817, dtype: object

# %%
Genre=[]
for x in list_Genre:
  Genre.extend(x)

# %%
df
# Out:
#       index                                Name    Year Duration  \
# 0         1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 1         3                             #Yaaram  (2019)  110 min
# 2         5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 3         6                           ...Yahaan  (2005)  142 min
# 4         8                  ?: A Question Mark  (2012)   82 min
# ...     ...                                 ...     ...      ...
# 7812  15501                     Zulm Ki Hukumat  (1992)      NaN
# 7813  15503                     Zulm Ki Zanjeer  (1989)  125 min
# 7814  15504                 Zulm Ko Jala Doonga  (1988)      NaN
# 7815  15505                               Zulmi  (1999)  129 min
# 7816  15508                        Zulm-O-Sitam  (1998)  130 min
#
#                           Genre  Rating  Votes           Director  \
# 0                         Drama     7.0      8      Gaurav Bakshi
# 1               Comedy, Romance     4.4     35         Ovais Khan
# 2        Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 3           Drama, Romance, War     7.4  1,086     Shoojit Sircar
# 4     Horror, Mystery, Thriller     5.6    326      Allyson Patel
# ...                         ...     ...    ...                ...
# 7812       Action, Crime, Drama     5.3    135  Bharat Rangachary
# 7813       Action, Crime, Drama     5.8     44    S.P. Muthuraman
# 7814                     Action     4.6     11      Mahendra Shah
# 7815              Action, Drama     4.5    655         Kuku Kohli
# 7816              Action, Drama     6.2     20       K.C. Bokadia
#
#                Actor 1                 Actor 2          Actor 3
# 0         Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 1              Prateik              Ishita Raj  Siddhant Kapoor
# 2           Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 3      Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 4            Yash Dave          Muntazir Ahmad     Kiran Bhatia
# ...                ...                     ...              ...
# 7812        Dharmendra     Moushumi Chatterjee          Govinda
# 7813       Chiranjeevi              Jayamalini      Rajinikanth
# 7814  Naseeruddin Shah           Sumeet Saigal    Suparna Anand
# 7815      Akshay Kumar          Twinkle Khanna      Aruna Irani
# 7816        Dharmendra              Jaya Prada      Arjun Sarja
#
# [7817 rows x 11 columns]

# %%
Genres=[i.strip() for i in Genre]

# %%
df2=pd.DataFrame(Genres)

# %%
df2
# Out:
#              0
# 0        Drama
# 1       Comedy
# 2      Romance
# 3       Comedy
# 4        Drama
# ...        ...
# 15730   Action
# 15731   Action
# 15732    Drama
# 15733   Action
# 15734    Drama
#
# [15735 rows x 1 columns]

# %%
df2.columns=["Genre"]

# %%
count_of_genre=df2["Genre"].value_counts()
count_of_genre
# Out:
# Drama          4924
# Action         2358
# Romance        1781
# Comedy         1609
# Crime          1111
# Thriller        876
# Family          663
# Musical         498
# Adventure       386
# Mystery         370
# Horror          280
# Fantasy         205
# Documentary     143
# Biography       142
# History         128
# Animation        73
# Music            61
# Sport            51
# Sci-Fi           37
# War              34
# Western           3
# News              2
# Name: Genre, dtype: int64

# %%
listOfGenre=df2["Genre"].unique()
listOfGenre
# Out:
# array(['Drama', 'Comedy', 'Romance', 'Musical', 'War', 'Horror',
#        'Mystery', 'Thriller', 'Action', 'Crime', 'History', 'Family',
#        'Adventure', 'Sci-Fi', 'Sport', 'Biography', 'Fantasy',
#        'Documentary', 'Music', 'Animation', 'News', 'Western'],
#       dtype=object)

# %%
len(listOfGenre)
# Out:
# 22

# %%
labels=['Drama', 'Comedy', 'Romance', 'Musical', 'War', 'Horror','Mystery', 'Thriller', 'Action', 'Crime', 'History', 'Family','Adventure', 'Sci-Fi', 'Sport', 'Biography', 'Fantasy','Documentary', 'Music', 'Animation', 'News', 'Western']
plt.pie(count_of_genre, labels = labels)
plt.title('Count of genre')
plt.show()

# %%
plt.barh(listOfGenre,count_of_genre)
plt.title('count of Genre')
plt.xlabel('list Of Genre')
plt.ylabel('count of genre')
plt.figure(figsize=(155,100))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7817 entries, 0 to 7816
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     7817 non-null   int64
#  1   Name      7817 non-null   object
#  2   Year      7817 non-null   object
#  3   Duration  5820 non-null   object
#  4   Genre     7817 non-null   object
#  5   Rating    7817 non-null   float64
#  6   Votes     7817 non-null   object
#  7   Director  7812 non-null   object
#  8   Actor 1   7707 non-null   object
#  9   Actor 2   7641 non-null   object
#  10  Actor 3   7558 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 671.9+ KB

# %%
listOfRate=[]
listOfRate=df['Rating']
listOfRate
# Out:
# 0       7.0
# 1       4.4
# 2       4.7
# 3       7.4
# 4       5.6
#        ...
# 7812    5.3
# 7813    5.8
# 7814    4.6
# 7815    4.5
# 7816    6.2
# Name: Rating, Length: 7817, dtype: float64
